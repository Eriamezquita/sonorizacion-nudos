# %% [markdown]
# # 00. Inicio del proyecto\n\nPrimer notebook para explorar la ruta:\n\n`nudo → representación → secuencia → mapeo → sonido → visualización`\n

# %%
from src.knots import trefoil_descriptor\nfrom src.sonification import sequence_to_events\n\nknot = trefoil_descriptor()\nsequence = knot.as_event_sequence()\nevents = sequence_to_events(sequence)\n\nknot, sequence, events

# %% [markdown]
# ## Preguntas de trabajo\n\n1. ¿Qué propiedad matemática se está escuchando?\n2. ¿Qué parte del mapeo es formal y qué parte es decisión estética?\n3. ¿El resultado permite distinguir un nudo de otro?\n4. ¿Qué se pierde al traducir estructura matemática a sonido?\n
